# %% [markdown]
# # Regularization

# %% [markdown]
# ## Import Necessary Libraries

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression, Lasso, Ridge

# %% [markdown]
# ## Data Preparation

# %%
dataframe = pd.read_csv('../data/data.csv')
dataframe.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
#    yr_renovated                    street       city  statezip country
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0           709 W Blaine St    Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042     USA
# 3             0           857 170th Pl NE   Bellevue  WA 98008     USA
# 4          1992         9105 170th Ave NE    Redmond  WA 98052     USA

# %%
dataframe.shape
# Out:
# (4600, 18)

# %%
dataframe.nunique()
# Out:
# date               70
# price            1741
# bedrooms           10
# bathrooms          26
# sqft_living       566
# sqft_lot         3113
# floors              6
# waterfront          2
# view                5
# condition           5
# sqft_above        511
# sqft_basement     207
# yr_built          115
# yr_renovated       60
# street           4525
# city               44
# statezip           77
# country             1
# dtype: int64

# %% [markdown]
# ## Dropping of Tables
#
# - Date
# - Year Built
# - Year Renovated
# - Street
# - StateZip
# - Country

# %%
new_dataframe = dataframe.drop(columns=['date', 'yr_built', 'yr_renovated', 'street', 'statezip', 'country'])
new_dataframe.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0       3.0       1.50         1340      7912     1.5           0
# 1  2384000.0       5.0       2.50         3650      9050     2.0           0
# 2   342000.0       3.0       2.00         1930     11947     1.0           0
# 3   420000.0       3.0       2.25         2000      8030     1.0           0
# 4   550000.0       4.0       2.50         1940     10500     1.0           0
#
#    view  condition  sqft_above  sqft_basement       city
# 0     0          3        1340              0  Shoreline
# 1     4          5        3370            280    Seattle
# 2     0          4        1930              0       Kent
# 3     0          4        1000           1000   Bellevue
# 4     0          4        1140            800    Redmond

# %%
new_dataframe.isna().sum()
# Out:
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# city             0
# dtype: int64

# %%
new_dataframe.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# min       1.000000     0.000000     0.000000     1.000000   370.000000
# 25%       1.000000     0.000000     0.000000     3.000000  1190.000000
# 50%       1.500000     0.000000     0.000000     3.000000  1590.000000
# 75%       2.000000     0.000000     0.000000     4.000000  2300.000000
# max       3.500000     1.000000     4.000000     5.000000  9410.000000
#
#        sqft_basement
# count    4600.000000
# mean      312.081522
# std       464.137228
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       610.000000
# max      4820.000000

# %%
(new_dataframe['price'] == 0).sum()
# Out:
# 49

# %%
new_dataframe[new_dataframe['price'] == 0] = new_dataframe['price'].mean()
new_dataframe
# Out:
#              price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     3.130000e+05       3.0       1.50       1340.0    7912.0     1.5
# 1     2.384000e+06       5.0       2.50       3650.0    9050.0     2.0
# 2     3.420000e+05       3.0       2.00       1930.0   11947.0     1.0
# 3     4.200000e+05       3.0       2.25       2000.0    8030.0     1.0
# 4     5.500000e+05       4.0       2.50       1940.0   10500.0     1.0
# ...            ...       ...        ...          ...       ...     ...
# 4595  3.081667e+05       3.0       1.75       1510.0    6360.0     1.0
# 4596  5.343333e+05       3.0       2.50       1460.0    7573.0     2.0
# 4597  4.169042e+05       3.0       2.50       3010.0    7014.0     2.0
# 4598  2.034000e+05       4.0       2.00       2090.0    6630.0     1.0
# 4599  2.206000e+05       3.0       2.50       1490.0    8102.0     2.0
#
#       waterfront  view  condition  sqft_above  sqft_basement       city
# 0            0.0   0.0        3.0      1340.0            0.0  Shoreline
# 1            0.0   4.0        5.0      3370.0          280.0    Seattle
# 2            0.0   0.0        4.0      1930.0            0.0       Kent
# 3            0.0   0.0        4.0      1000.0         1000.0   Bellevue
# 4            0.0   0.0        4.0      1140.0          800.0    Redmond
# ...          ...   ...        ...         ...            ...        ...
# 4595         0.0   0.0        4.0      1510.0            0.0    Seattle
# 4596         0.0   0.0        3.0      1460.0            0.0   Bellevue
# 4597         0.0   0.0        3.0      3010.0            0.0     Renton
# 4598         0.0   0.0        3.0      1070.0         1020.0    Seattle
# 4599         0.0   0.0        4.0      1490.0            0.0  Covington
#
# [4600 rows x 12 columns]

# %%
new_dataframe.describe()
# Out:
#               price       bedrooms      bathrooms    sqft_living  \
# count  4.600000e+03    4600.000000    4600.000000    4600.000000
# mean   5.578426e+05    5882.964225    5881.737812    7989.263573
# std    5.609180e+05   56669.335946   56669.463215   56458.762508
# min    7.800000e+03       0.000000       0.000000     370.000000
# 25%    3.281589e+05       3.000000       1.750000    1470.000000
# 50%    4.687500e+05       3.000000       2.250000    1980.000000
# 75%    6.549625e+05       4.000000       2.500000    2632.500000
# max    2.659000e+07  551962.988473  551962.988473  551962.988473
#
#            sqft_lot         floors     waterfront           view  \
# count  4.600000e+03    4600.000000    4600.000000    4600.000000
# mean   2.055686e+04    5881.101834    5879.612269    5879.837921
# std    6.573262e+04   56669.529211   56669.683788   56669.660376
# min    6.380000e+02       1.000000       0.000000       0.000000
# 25%    5.002750e+03       1.000000       0.000000       0.000000
# 50%    7.700000e+03       1.500000       0.000000       0.000000
# 75%    1.120000e+04       2.000000       0.000000       0.000000
# max    1.074218e+06  551962.988473  551962.988473  551962.988473
#
#            condition     sqft_above  sqft_basement
# count    4600.000000    4600.000000    4600.000000
# mean     5883.018355    7682.416834    6186.452486
# std     56669.330326   56488.991876   56639.705592
# min         1.000000     370.000000       0.000000
# 25%         3.000000    1190.000000       0.000000
# 50%         3.000000    1600.000000       0.000000
# 75%         4.000000    2320.000000     620.000000
# max    551962.988473  551962.988473  551962.988473

# %%
new_dataframe.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0       3.0       1.50       1340.0    7912.0     1.5         0.0
# 1  2384000.0       5.0       2.50       3650.0    9050.0     2.0         0.0
# 2   342000.0       3.0       2.00       1930.0   11947.0     1.0         0.0
# 3   420000.0       3.0       2.25       2000.0    8030.0     1.0         0.0
# 4   550000.0       4.0       2.50       1940.0   10500.0     1.0         0.0
#
#    view  condition  sqft_above  sqft_basement       city
# 0   0.0        3.0      1340.0            0.0  Shoreline
# 1   4.0        5.0      3370.0          280.0    Seattle
# 2   0.0        4.0      1930.0            0.0       Kent
# 3   0.0        4.0      1000.0         1000.0   Bellevue
# 4   0.0        4.0      1140.0          800.0    Redmond

# %%
new_dataframe = pd.get_dummies(new_dataframe, drop_first=True)
new_dataframe.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0       3.0       1.50       1340.0    7912.0     1.5         0.0
# 1  2384000.0       5.0       2.50       3650.0    9050.0     2.0         0.0
# 2   342000.0       3.0       2.00       1930.0   11947.0     1.0         0.0
# 3   420000.0       3.0       2.25       2000.0    8030.0     1.0         0.0
# 4   550000.0       4.0       2.50       1940.0   10500.0     1.0         0.0
#
#    view  condition  sqft_above  ...  city_SeaTac  city_Seattle  \
# 0   0.0        3.0      1340.0  ...        False         False
# 1   4.0        5.0      3370.0  ...        False          True
# 2   0.0        4.0      1930.0  ...        False         False
# 3   0.0        4.0      1000.0  ...        False         False
# 4   0.0        4.0      1140.0  ...        False         False
#
#    city_Shoreline  city_Skykomish  city_Snoqualmie  city_Snoqualmie Pass  \
# 0            True           False            False                 False
# 1           False           False            False                 False
# 2           False           False            False                 False
# 3           False           False            False                 False
# 4           False           False            False                 False
#
#    city_Tukwila  city_Vashon  city_Woodinville  city_Yarrow Point
# 0         False        False             False              False
# 1         False        False             False              False
# 2         False        False             False              False
# 3         False        False             False              False
# 4         False        False             False              False
#
# [5 rows x 55 columns]

# %% [markdown]
# ## Assigning X and y
